# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='D:/RWF_Video/train/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start)
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start)
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 1600

# %%
x = [0] * 800
y =[1]*800
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                 entropy  label
# 0     0.11833931831154094 0.14843112253895635 0.4407...      0
# 1     0.328551501889026 0.30740080245159684 0.639009...      0
# 2     0.4929780597490751 0.40093410903971705 0.55440...      0
# 3     1.157160089330703 0.9648025398671042 0.8885060...      0
# 4     1.1558091212248869 0.6990940845907679 0.647114...      0
# ...                                                 ...    ...
# 1595  3.0772451842783286 2.8242657662519357 3.054968...      1
# 1596  2.441674463567843 2.1517618916023333 2.3813337...      1
# 1597  1.407669219667584 1.3016186445519513 1.2283685...      1
# 1598  0.577189168904591 0.24488494378794937 0.195572...      1
# 1599  0.9181068016298719 0.5999877462738202 0.633269...      1
#
# [1600 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/RWF_fight/CDI_Based/Entropy/CSV/Gray.csv')
display(data_df)
# Out:
#                         0                    1                    2  \
# 0     0.11833931831154094  0.14843112253895635   0.4407105089687285
# 1       0.328551501889026  0.30740080245159684   0.6390096716087578
# 2      0.4929780597490751  0.40093410903971705   0.5544045339694058
# 3       1.157160089330703   0.9648025398671042   0.8885060077346172
# 4      1.1558091212248869   0.6990940845907679   0.6471149697053509
# ...                   ...                  ...                  ...
# 1595   3.0772451842783286   2.8242657662519357   3.0549682315143922
# 1596    2.441674463567843   2.1517618916023333   2.3813337667492696
# 1597    1.407669219667584   1.3016186445519513    1.228368577275432
# 1598    0.577189168904591  0.24488494378794937  0.19557216327622778
# 1599   0.9181068016298719   0.5999877462738202   0.6332698768660197
#
#                         3                    4                   5  \
# 0     0.41999171648434397     0.88707030593629  0.8108895071741992
# 1      0.5067121445117717   0.9349496877041602  1.1483759039333545
# 2      0.7187306204451351   0.5089294882910061  0.4649118618141366
# 3      0.8592281522224803   0.8383178066170062  0.8968353407010393
# 4      0.6760420910684585   0.5775408197353197  0.5593022882645856
# ...                   ...                  ...                 ...
# 1595    3.066268882079297    2.844731404245913  2.9792369547145774
# 1596   2.2836061812475803   2.3231334166163533   2.966013537658555
# 1597    1.198593343601857   1.1978178119413336  0.9758720592840463
# 1598  0.17192433211174601  0.20614257104267597  0.4923722074221871
# 1599   0.5855969664307266   0.6275366014537613  0.6080874576827998
#
