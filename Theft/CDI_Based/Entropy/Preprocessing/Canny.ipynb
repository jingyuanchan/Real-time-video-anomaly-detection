# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Theft/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'
# Out:
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Theft\CDI_Based\Entropy\Preprocessing\image_preprocessing\cdi_process.ipynb
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Theft\CDI_Based\Entropy\Preprocessing\image_preprocessing\calc_entropy.ipynb

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='CANNY')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='CANNY')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 268

# %%
x = [0] * 145
y =[1]*123
z=x+y
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.01236756343197186 0.011996942579313644 0.012...      0
# 1    0.017886438703358508 0.020637734376283693 0.02...      0
# 2    0.036497983096985716 0.022619724775722907 0.02...      0
# 3    0.007742286198566164 0.004392430343852098 0.00...      0
# 4    0.014389887672092245 0.006769678351868611 0.00...      0
# ..                                                 ...    ...
# 263  0.004306441856315063 0.005223499934272866 0.00...      1
# 264  0.016210290260861942 0.01510126610214499 0.015...      1
# 265  0.003417534182578364 0.0028724248139270414 0.0...      1
# 266  0.03167225010741994 0.03588171214548776 0.0322...      1
# 267  0.0002587246935693652 0.0031019743328746002 0....      1
#
# [268 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Theft/CDI_Based/Entropy/CSV/Canny.csv')
display(data_df)
# Out:
#                          0                      1                      2  \
# 0      0.01236756343197186   0.011996942579313644   0.012396035895209552
# 1     0.017886438703358508   0.020637734376283693    0.02001422245016546
# 2     0.036497983096985716   0.022619724775722907    0.02327039418062646
# 3     0.007742286198566164   0.004392430343852098   0.003962436191845605
# 4     0.014389887672092245   0.006769678351868611  0.0032166924099539178
# ..                     ...                    ...                    ...
# 263   0.004306441856315063   0.005223499934272866   0.004363796666141387
# 264   0.016210290260861942    0.01510126610214499   0.015584786498765001
# 265   0.003417534182578364  0.0028724248139270414  0.0012645495302892587
# 266    0.03167225010741994    0.03588171214548776   0.032262394722461424
# 267  0.0002587246935693652  0.0031019743328746002   0.008714313557024416
#
#                          3                      4                     5  \
# 0     0.012167984261565927    0.02046764422725959   0.01672189605399723
# 1      0.02128925607504029   0.022223554790148644  0.016551409992707065
# 2     0.028943155982536745   0.024203347800106908   0.01765928122581853
# 3    0.0028436749015722214    0.00734187620857014  0.009599920047153888
# 4     0.002556744951735056   0.008885753485092998    0.0105420780646338
# ..                     ...                    ...                   ...
# 263   0.002527988712266334    0.00416308763699066  0.005338047955021734
# 264    0.01930526764224379   0.014503695083895575   0.01868115493116611
# 265   0.002728926973927738  0.0034748388459821416  0.005624506253871977
# 266     0.0361339183167474    0.03946333464164583   0.04253362814584112
