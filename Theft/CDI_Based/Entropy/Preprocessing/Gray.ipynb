# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Theft/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'
# Out:
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Theft\CDI_Based\Entropy\Preprocessing\image_preprocessing\cdi_process.ipynb
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Theft\CDI_Based\Entropy\Preprocessing\image_preprocessing\calc_entropy.ipynb

# %%
video=os.listdir(positive_os)

for i in video:
    video_name=positive_os+i
    #print(video_name)
    cap = cv.VideoCapture(video_name)
    num=cap.get(7)
    if num!=30:
        print(i)
    while 1:
        ret,frame=cap.read() 
        if ret:
            cv.imshow('frame',frame)
            k = cv.waitKey(1) 
            if k ==27:     
                break 
        else:
            break
cv.destroyAllWindows()

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start)
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start)
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 268

# %%
x = [0] * 145
y =[1]*123
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.9663460008950181 0.7792133015379795 0.802230...      0
# 1    1.1797922171822337 1.2109485902318784 1.059227...      0
# 2    1.738854912969758 1.308500968231926 1.23152973...      0
# 3    0.8621400647193093 0.4901173466361787 0.473372...      0
# 4    0.7078152925175902 0.46523532092370823 0.23432...      0
# ..                                                 ...    ...
# 263  0.6414723943364027 0.6934912733320931 0.510577...      1
# 264  1.2389361351197437 1.1784074790482972 1.165910...      1
# 265  0.4832715691279457 0.3860012361993731 0.219963...      1
# 266  1.6525444835857637 1.6457660348932186 1.639262...      1
# 267  0.06626219938162513 0.4976116423571522 0.81694...      1
#
# [268 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Theft/CDI_Based/Entropy/CSV/Gray.csv')
display(data_df)
# Out:
#                        0                    1                    2  \
# 0     0.9663460008950181   0.7792133015379795   0.8022301282889053
# 1     1.1797922171822337   1.2109485902318784   1.0592278533153108
# 2      1.738854912969758    1.308500968231926   1.2315297388380972
# 3     0.8621400647193093   0.4901173466361787  0.47337298464430155
# 4     0.7078152925175902  0.46523532092370823   0.2343254736195455
# ..                   ...                  ...                  ...
# 263   0.6414723943364027   0.6934912733320931   0.5105772269064582
# 264   1.2389361351197437   1.1784074790482972   1.1659101512222254
# 265   0.4832715691279457   0.3860012361993731   0.2199636844542589
# 266   1.6525444835857637   1.6457660348932186   1.6392629556393452
# 267  0.06626219938162513   0.4976116423571522   0.8169485566543107
#
#                        3                    4                    5  \
# 0     0.8251822534164422   0.7525377424709986   0.7162139473976613
# 1     1.0191966685051421   1.2264833560355006   0.9883406662564841
# 2     1.5354911841969539   1.4284617116449194   1.0095696608138869
# 3     0.4763471996011547   0.7581501051636563   0.9547389209228573
# 4    0.27367287480393043   0.5938022277189741   0.6608449606106075
# ..                   ...                  ...                  ...
# 263  0.48623726039702553    0.476273019991458  0.47835393116160435
# 264   1.3374150061207708   1.2165026727713932   1.2470962914562607
# 265  0.19170652899647028  0.21156961720870315  0.31501353654558595
# 266    1.693136434064347   1.6663363016456152   1.8084622721009516
# 267   0.7899092460087436   1.7483046278179726   0.5047388173501507
#
#                        6                    7                    8  \
