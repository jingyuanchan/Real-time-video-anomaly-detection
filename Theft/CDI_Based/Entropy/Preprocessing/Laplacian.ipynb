# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Theft/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='LAPLACIAN')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='LAPLACIAN')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 268

# %%
x = [0] * 145
y =[1]*123
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    1.186143113636482 0.9854499779751562 1.0167966...      0
# 1    1.2995476844845586 1.3365221392761049 1.209233...      0
# 2    1.7761170628305138 1.2982049262860196 1.225182...      0
# 3    1.0133383717995212 0.5604282641057234 0.466119...      0
# 4    0.9564315552969012 0.6529477109134324 0.329586...      0
# ..                                                 ...    ...
# 263  0.7506454510635703 0.8081703374799174 0.680421...      1
# 264  1.2453589844594162 1.145619353979105 1.1280056...      1
# 265  0.5977576048391884 0.4549378899986232 0.211204...      1
# 266  1.406167169893727 1.3747867621768932 1.3909014...      1
# 267  0.08202915579313177 0.5455356328174137 0.88005...      1
#
# [268 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Theft/CDI_Based/Entropy/CSV/Laplacian.csv')
display(data_df)
# Out:
#                        0                   1                    2  \
# 0      1.186143113636482  0.9854499779751562   1.0167966014364755
# 1     1.2995476844845586  1.3365221392761049   1.2092333388127094
# 2     1.7761170628305138  1.2982049262860196    1.225182606755117
# 3     1.0133383717995212  0.5604282641057234   0.4661198612593657
# 4     0.9564315552969012  0.6529477109134324   0.3295867024236022
# ..                   ...                 ...                  ...
# 263   0.7506454510635703  0.8081703374799174    0.680421813542215
# 264   1.2453589844594162   1.145619353979105   1.1280056670542535
# 265   0.5977576048391884  0.4549378899986232  0.21120455008463596
# 266    1.406167169893727  1.3747867621768932    1.390901448832025
# 267  0.08202915579313177  0.5455356328174137   0.8800574595755435
#
#                        3                    4                    5  \
# 0     1.0480192398421586   0.9694571099063882   0.9239746319679532
# 1     1.1314077017685817   1.2725536259401882   1.1129745491989824
# 2     1.5701334612652933   1.4665098419774316   1.0104640848433053
# 3     0.5030742296484921   0.8910316544919402    1.120166627013173
# 4    0.37529378095492694   0.8151288569037887   0.9148435032313483
# ..                   ...                  ...                  ...
# 263   0.6255252309186999   0.6112272582360448    0.599527991116871
# 264   1.2746339351224345   1.1781912858184513   1.1582651302117628
# 265  0.16445443849029012  0.17270187452920663  0.27190986615335005
# 266   1.4419351732573433   1.3950899655761761   1.4560504587844383
# 267   0.8418475666727835   1.4467741419976543   0.5473736044032039
