# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Fight/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'
# Out:
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Fight\CDI_Based\Entropy\Preprocessing\image_preprocessing\cdi_process.ipynb
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Fight\CDI_Based\Entropy\Preprocessing\image_preprocessing\calc_entropy.ipynb

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='HARRIS')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='HARRIS')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 247

# %%
x = [0] * 159
y =[1]*88
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.20202175702206185 0.3044518828854916 0.23052...      0
# 1    0.2473338164348534 0.537482800783945 0.3186846...      0
# 2    0.35377868564282827 0.40835676734844395 0.6073...      0
# 3    0.6126158986898004 0.22613404502970944 0.16922...      0
# 4    0.32077595892647204 0.31875001887578475 0.2231...      0
# ..                                                 ...    ...
# 242  0.14030393876294006 0.3505113638237059 0.39130...      1
# 243  0.23873825566908166 0.21545872740134345 0.2684...      1
# 244  0.49068904036025857 0.3317791505025425 0.54872...      1
# 245  0.2851518209276428 0.2452283269307312 0.132109...      1
# 246  0.2837599383572215 0.26123166500397943 0.34684...      1
#
# [247 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Fight/CDI_Based/Entropy/CSV/Harris.csv')
display(data_df)
# Out:
#                        0                    1                    2  \
# 0    0.20202175702206185   0.3044518828854916  0.23052799486444436
# 1     0.2473338164348534    0.537482800783945  0.31868469941956834
# 2    0.35377868564282827  0.40835676734844395   0.6073766530174747
# 3     0.6126158986898004  0.22613404502970944  0.16922893758716487
# 4    0.32077595892647204  0.31875001887578475  0.22311179881090015
# ..                   ...                  ...                  ...
# 242  0.14030393876294006   0.3505113638237059   0.3913027232652735
# 243  0.23873825566908166  0.21545872740134345  0.26844196731493475
# 244  0.49068904036025857   0.3317791505025425   0.5487278566154064
# 245   0.2851518209276428   0.2452283269307312  0.13210918471428199
# 246   0.2837599383572215  0.26123166500397943   0.3468446714382975
#
#                        3                    4                    5  \
# 0    0.18274619315601578  0.05994999519376809  0.02983215226363442
# 1    0.39347083690272827  0.23778406567847488  0.21586474565301086
# 2     0.4462262937693611   0.5398341658661657  0.16619728230772518
# 3    0.16020518455095722  0.19923004377254216   0.5220878294638274
# 4    0.15301399713259592  0.19027192570339568   0.1579098935672679
# ..                   ...                  ...                  ...
# 242  0.19187444251143043  0.19303187457173404   0.3640349039554212
# 243  0.17188349479309895  0.19112625625414625  0.26426817159966975
# 244   0.6254268754449809   0.7487047971293646   0.7587687971855109
