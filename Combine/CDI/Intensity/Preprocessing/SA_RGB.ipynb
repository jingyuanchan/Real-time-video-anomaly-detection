# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit

from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')
datasets=['Explosion','Road_Accident','Fighting','Robbery','Burglary']
for data_name in datasets:
    
    Home_os='D:/new/'+data_name+'/'
    negative_os=Home_os+'negative/'
    positive_os=Home_os+'positive/'
    video=os.listdir(negative_os)
    
    
    Intensity_list=[]
    for i in video:
        start=0
        video_name=negative_os+i
        cap = cv.VideoCapture(video_name)
        My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
        in_list=[]
        while 1:
            if start<=27:
                cdi,frame=My_CDI.CDI(start,image_type='BGR',methods='SALIENCY')
                Intensity=My_CDI.CDI_Intensity(cdi,Normalization=False)
                in_list.append(Intensity)
                cv.imshow('frame',frame)
                cv.imshow('cdi',cdi)
                k = cv.waitKey(1) 
                start+=1
                if k ==27:     
                    break 
            else:
                break
        Intensity_list.append(in_list)
        cap.release()
    cv.destroyAllWindows() 
    
    video=os.listdir(positive_os)
    #My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
    P_Intensity_list=[]
    for i in video:
        start=0
        video_name=positive_os+i
        cap = cv.VideoCapture(video_name)
        My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
        in_list=[]
        while 1:
            if start<=27:
                cdi,frame=My_CDI.CDI(start,image_type='BGR',methods='SALIENCY')
                Intensity=My_CDI.CDI_Intensity(cdi,Normalization=False)
                in_list.append(Intensity)
                cv.imshow('frame',frame)
                cv.imshow('cdi',cdi)
                k = cv.waitKey(1) 
                start+=1
                if k ==27:     
                    break 
            else:
                break
        P_Intensity_list.append(in_list)
        cap.release()
    cv.destroyAllWindows() 
    
    
    Combine_Intensity=Intensity_list+P_Intensity_list
#     min_max_scaler =MinMaxScaler()
#     for i in range(len(Combine_Intensity)):
#         Combine_Intensity[i] = ((min_max_scaler.fit_transform(np.array(Combine_Intensity[i]).reshape(-1,1)))).reshape(-1).tolist()
    new_list=[]
    for i in Combine_Intensity:
            str1 = ' '.join([str(x) for x in i])
            new_list.append(str1)

    print(len(new_list))
    x = [0] * len(Intensity_list)
    y =[1]*len(P_Intensity_list)
    z=x+y
    combine_dict={'intensity':new_list,'label':z}
    df=pd.DataFrame(combine_dict)

    display(df)
    y=df['label'].values

    data_df = df['intensity'].str.split(' ', expand=True)

    data_df['Class'] =y
    data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Combine/CDI/Intensity/CSV/'+data_name+'/SA_RGB.csv')
    display(data_df)
# Out:
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Combine\CDI\Intensity\Preprocessing\image_preprocessing\cdi_process.ipynb
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Combine\CDI\Intensity\Preprocessing\image_preprocessing\calc_entropy.ipynb
# 268
#                                              intensity  label
# 0    2519910 2852940 2779755 1862520 1448655 158814...      0
# 1    4287825 4423995 4167465 3146700 2560455 317832...      0
# 2    8634555 7524540 7668360 8832180 8235990 769998...      0
# 3    5272635 5586285 6655755 7291470 7289175 692656...      0
# 4    6743475 6669525 7211655 6412995 7127250 778770...      0
# ..                                                 ...    ...
# 263  5715570 5612040 5184915 5880555 6012135 598485...      1
# 264  2879460 3580455 2001240 2697900 8314530 468460...      1
# 265  534990 463845 701505 8190855 7814220 7587015 7...      1
# 266  8299230 8260980 7527600 7943760 11554305 74926...      1
# 267  4275585 5024775 6804420 7431720 8331615 927486...      1
#
# [268 rows x 2 columns]
#            0        1        2        3         4        5         6        7  \
# 0    2519910  2852940  2779755  1862520   1448655  1588140   1090125  1287750
# 1    4287825  4423995  4167465  3146700   2560455  3178320   2847075  2337075
# 2    8634555  7524540  7668360  8832180   8235990  7699980   8288775  8565705
# 3    5272635  5586285  6655755  7291470   7289175  6926565   6727155  6933705
