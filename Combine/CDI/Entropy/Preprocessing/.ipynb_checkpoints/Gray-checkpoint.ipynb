# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Fire/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'
# Out:
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Fire\CDI_Based\Entropy\Preprocessing\image_preprocessing\cdi_process.ipynb
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Fire\CDI_Based\Entropy\Preprocessing\image_preprocessing\calc_entropy.ipynb

# %%
video=os.listdir(positive_os)

for i in video:
    video_name=positive_os+i
    #print(video_name)
    cap = cv.VideoCapture(video_name)
    num=cap.get(7)
    if num!=30:
        print(i)
    while 1:
        ret,frame=cap.read() 
        if ret:
            cv.imshow('frame',frame)
            k = cv.waitKey(1) 
            if k ==27:     
                break 
        else:
            break
cv.destroyAllWindows()

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start)
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start)
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 268

# %%
x = [0] * 126
y =[1]*142
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.8374959794429149 0.8048838263492873 0.694753...      0
# 1    0.8533556205600853 0.7016164975140964 0.622519...      0
# 2    1.8947321989224382 1.7192721355510103 1.599109...      0
# 3    0.8347483386714071 0.8636272636285135 1.048542...      0
# 4    1.6288940757631445 1.3859161375565001 1.244579...      0
# ..                                                 ...    ...
# 263  2.0634750907956017 2.185342881112701 2.0801689...      1
# 264  0.3393931882796879 0.5077188228169456 0.287133...      1
# 265  0.06158913806103147 0.04517388344215329 0.0311...      1
# 266  2.6087484296429855 2.6337939882369206 3.209031...      1
# 267  0.5109907870861501 0.4253429111388601 1.058202...      1
#
# [268 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Fire/CDI_Based/Entropy/CSV/Gray.csv')
display(data_df)
# Out:
#                        0                    1                     2  \
# 0     0.8374959794429149   0.8048838263492873    0.6947539155991875
# 1     0.8533556205600853   0.7016164975140964    0.6225197471158449
# 2     1.8947321989224382   1.7192721355510103    1.5991091673891733
# 3     0.8347483386714071   0.8636272636285135    1.0485424388823041
# 4     1.6288940757631445   1.3859161375565001    1.2445793312471025
# ..                   ...                  ...                   ...
# 263   2.0634750907956017    2.185342881112701     2.080168926494899
# 264   0.3393931882796879   0.5077188228169456    0.2871339765489474
# 265  0.06158913806103147  0.04517388344215329  0.031182381444060756
# 266   2.6087484296429855   2.6337939882369206     3.209031942263917
# 267   0.5109907870861501   0.4253429111388601     1.058202760203405
#
#                       3                   4                   5  \
# 0    0.5892480677283125  0.5538412878791616  0.4883358735169411
# 1    0.5966949600712675  0.5727903179523982  0.5818540622327161
# 2    1.6953620380669705  1.7681300854371316  1.6182079298420415
# 3     1.211607964755552  0.9895841498777468  1.0780145042515212
# 4    1.1197884883329918  1.3411777596405585  1.4616735273408408
# ..                  ...                 ...                 ...
# 263  2.5050296928180966  2.8570929333967685  2.7926082171367796
# 264  0.3912465281439643  2.8791036007696156  1.6523930036199455
# 265   1.901941939965152   2.560622718748001  2.6439181775530947
# 266   3.326925779615612  5.0539803089538715  2.5652611206308356
# 267  1.5161231916345568  1.8976719049092154  1.6238677658311607
#
#                        6                   7                   8  \
