# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Fire/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'
# Out:
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Fire\CDI_Based\Trace\Preprocessing\image_preprocessing\cdi_process.ipynb
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Fire\CDI_Based\Trace\Preprocessing\image_preprocessing\calc_entropy.ipynb

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='HARRIS')
            intensity=np.trace(cdi)
            in_list.append(intensity)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='HARRIS')
            intensity=np.trace(cdi)
            in_list.append(intensity)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 268

# %%
x = [0] * 126
y =[1]*142
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.0009014609 0.00096095423 0.000854537 0.00045...      0
# 1    0.0003395327 0.00011724636 0.00010857449 0.000...      0
# 2    0.002051803 0.0021656188 0.0018624197 0.004311...      0
# 3    0.00087554514 0.001161209 0.0051198686 0.00184...      0
# 4    0.0023831835 0.0011241677 0.0010974562 0.00152...      0
# ..                                                 ...    ...
# 263  0.0037647234 0.009515373 0.005493146 0.0041738...      1
# 264  0.00010235911 3.5845653e-05 2.0266212e-05 1.38...      1
# 265  8.5269314e-10 0.0 0.0 0.00025694264 0.00074277...      1
# 266  0.0010837573 0.0018109845 0.002440313 0.002335...      1
# 267  0.0005084879 0.0006051708 0.005249017 0.019423...      1
#
# [268 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Fire/CDI_Based/Trace/CSV/Harris.csv')
display(data_df)
# Out:
#                  0              1              2              3  \
# 0     0.0009014609  0.00096095423    0.000854537  0.00045510253
# 1     0.0003395327  0.00011724636  0.00010857449  0.00030283182
# 2      0.002051803   0.0021656188   0.0018624197   0.0043116957
# 3    0.00087554514    0.001161209   0.0051198686   0.0018497987
# 4     0.0023831835   0.0011241677   0.0010974562   0.0015276284
# ..             ...            ...            ...            ...
# 263   0.0037647234    0.009515373    0.005493146    0.004173836
# 264  0.00010235911  3.5845653e-05  2.0266212e-05  1.3810494e-05
# 265  8.5269314e-10            0.0            0.0  0.00025694264
# 266   0.0010837573   0.0018109845    0.002440313   0.0023358434
# 267   0.0005084879   0.0006051708    0.005249017     0.01942358
#
#                  4              5              6              7             8  \
# 0    0.00034555382   0.0002499615  0.00038808433   0.0003405391  0.0008042055
# 1    0.00031796994  0.00026803295  0.00016732283   8.568807e-05  0.0001529458
# 2      0.005118921   0.0055588735   0.0030587611   0.0023761292  0.0022623136
# 3      0.005700603   0.0064505036   0.0055211773   0.0052203257  0.0056483876
# 4     0.0052577937   0.0040419833    0.005389358    0.004299343  0.0050781486
# ..             ...            ...            ...            ...           ...
# 263   0.0053568445    0.014513211   0.0003986464   0.0008580901  0.0033298915
# 264  0.00023199603  0.00031443033  5.8988107e-06  0.00022286682  4.146582e-06
# 265   0.0007427757   0.0017226823    0.000698884   0.0011061025  0.0014728209
# 266   0.0035028677    0.000656347  0.00044451535   0.0005070689   0.000609476
# 267   0.0040745684   0.0015086825  0.00035042423   0.0012451579    0.00105802
#
#                  9  ...             19             20             21  \
# 0     0.0005743871  ...   0.0021193565    0.004821525    0.060952786
# 1    0.00021631173  ...  0.00025732664  0.00030947686  0.00022489803
# 2     0.0028463656  ...   0.0068462933   0.0031202966   0.0020313794
# 3      0.011046122  ...            0.0            0.0            0.0
# 4    0.00035442915  ...   0.0017853947   0.0007069034    0.002173504
# ..             ...  ...            ...            ...            ...
# 263   0.0027665526  ...   0.0030070068   0.0021403914    0.004769931
# 264  2.4396313e-06  ...  0.00013061508   7.364321e-05  0.00017601284
# 265   0.0012278375  ...   0.0011492544  0.00061541033   0.0012001891
# 266  0.00035011742  ...   0.0036820034   0.0074288845   0.0015303693
# 267   0.0016772642  ...     0.00294868   0.0043616453   0.0032049958
#
#                 22             23             24             25  \
# 0     0.0090932315    0.005505286    0.045162298    0.012704421
# 1     0.0002448539   0.0005221905  0.00043230335  0.00020438856
# 2     0.0032170657   0.0028802063    0.004512554   0.0024394318
# 3              0.0   2.257638e-08            0.0            0.0
# 4     0.0036118338   0.0017430582   0.0056688306    0.002372751
# ..             ...            ...            ...            ...
# 263   0.0017978684    0.003554704   0.0014632258   0.0012213225
# 264  0.00044360067   0.0004894253  0.00022270805  0.00032091065
# 265   0.0010468463    0.001839118  0.00084839767    0.000569565
# 266  0.00041469178  0.00046208984  0.00086474535   0.0007882191
# 267   0.0007668644  4.8951817e-05   6.375108e-05   8.357445e-05
#
#                 26             27 Class
# 0     0.0087747965   0.0032679758     0
# 1    0.00015277017   0.0001034919     0
# 2     0.0028662942   0.0038096334     0
# 3              0.0            0.0     0
# 4      0.006638634   0.0033624906     0
# ..             ...            ...   ...
# 263   0.0008674391   0.0019758036     1
# 264  0.00015832504  0.00026640866     1
# 265  0.00024735002   0.0014110858     1
# 266  0.00059653487   0.0009811391     1
# 267  3.9501094e-05  2.8978824e-05     1
#
# [268 rows x 29 columns]
