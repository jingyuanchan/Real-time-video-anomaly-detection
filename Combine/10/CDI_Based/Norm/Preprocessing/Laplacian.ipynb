# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Fire/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='LAPLACIAN')
            #cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            intensity=np.linalg.norm(cdi,ord=2)
            in_list.append(intensity)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='LAPLACIAN')
            #cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            intensity=np.linalg.norm(cdi,ord=2)
            in_list.append(intensity)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 268

# %%
x = [0] * 126
y =[1]*142
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    157.4864762678612 152.10113386208081 131.72471...      0
# 1    179.45710093639667 152.64483641403234 142.7718...      0
# 2    419.7830554455704 374.00424965931865 338.61682...      0
# 3    322.63254641643454 297.55873667770015 436.1342...      0
# 4    476.4652546089281 457.29080622820396 427.26569...      0
# ..                                                 ...    ...
# 263  427.5304336930201 522.6597410165157 412.333470...      1
# 264  101.64704258163843 139.2579464303652 73.827501...      1
# 265  15.640492353850806 16.218343028151388 11.65853...      1
# 266  301.1164898372589 306.24896121697935 443.88681...      1
# 267  199.55523951432556 204.29492569774635 313.5715...      1
#
# [268 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Fire/CDI_Based/Norm/CSV/Laplacian.csv')
display(data_df)
# Out:
#                       0                   1                   2  \
# 0     157.4864762678612  152.10113386208081  131.72471594838711
# 1    179.45710093639667  152.64483641403234  142.77189445432435
# 2     419.7830554455704  374.00424965931865    338.616827319217
# 3    322.63254641643454  297.55873667770015   436.1342514595356
# 4     476.4652546089281  457.29080622820396   427.2656966326448
# ..                  ...                 ...                 ...
# 263   427.5304336930201   522.6597410165157   412.3334702542099
# 264  101.64704258163843   139.2579464303652   73.82750164067205
# 265  15.640492353850806  16.218343028151388   11.65853991629047
# 266   301.1164898372589  306.24896121697935    443.886811093389
# 267  199.55523951432556  204.29492569774635   313.5715162997882
#
#                       3                   4                   5  \
# 0    107.12101603729586  105.32321026609299   98.01974947979235
# 1     137.6626843238141  122.65842700792449   122.3683711409819
# 2     351.2601622209474   346.8301608133321   560.6335790935908
# 3      558.286439527503   540.1184954973917    724.537086543519
# 4    393.86663340955795   417.7184871464154  470.19563967305703
# ..                  ...                 ...                 ...
# 263   418.6611273945605   413.4614006329285   430.9694546064331
# 264   86.66566460623844  276.94033323344195   179.2376388622149
# 265  210.95731117487333  268.44917820449666   286.0105078189828
