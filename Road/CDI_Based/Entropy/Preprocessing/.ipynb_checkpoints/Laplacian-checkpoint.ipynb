# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Road/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='LAPLACIAN')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='LAPLACIAN')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 299

# %%
x = [0] * 198
y =[1]*101
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)


display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.11443805397567833 0.14018411660227956 0.1170...      0
# 1    0.348783098081774 0.45715500969559125 0.459225...      0
# 2    1.1921004452785886 1.171015999667407 1.3087299...      0
# 3    0.838409669130683 0.7039690158136864 1.2908605...      0
# 4    0.9666795131062784 1.013763719280886 0.8596042...      0
# ..                                                 ...    ...
# 294  0.31349889392321795 0.21549205016255152 0.2048...      1
# 295  0.6163852550431769 0.5803551511345496 0.881676...      1
# 296  0.49726994622201537 0.1355044808869565 0.13739...      1
# 297  0.7272275513714096 0.26388876450076265 0.26970...      1
# 298  0.8873183036755334 1.0290211276981187 1.273818...      1
#
# [299 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Road/CDI_Based/Entropy/CSV/Laplacian.csv')
display(data_df)
# Out:
#                        0                    1                    2  \
# 0    0.11443805397567833  0.14018411660227956  0.11709890109224008
# 1      0.348783098081774  0.45715500969559125  0.45922513477078813
# 2     1.1921004452785886    1.171015999667407   1.3087299396884726
# 3      0.838409669130683   0.7039690158136864    1.290860592057674
# 4     0.9666795131062784    1.013763719280886    0.859604255856045
# ..                   ...                  ...                  ...
# 294  0.31349889392321795  0.21549205016255152  0.20480910993868245
# 295   0.6163852550431769   0.5803551511345496   0.8816767977297477
# 296  0.49726994622201537   0.1355044808869565  0.13739994329334818
# 297   0.7272275513714096  0.26388876450076265    0.269701573790606
# 298   0.8873183036755334   1.0290211276981187   1.2738185173473824
#
#                        3                    4                     5  \
# 0    0.09046170537475522  0.06153635623489545  0.058827046123495014
# 1     0.3683807186554792  0.42502541268227517   0.40095858713289245
# 2     1.3531331055461737   1.4018358440445489    1.4013348219292496
# 3      1.205246872287756   0.7162648848570176    0.3639220265719069
# 4     0.7311582845487389    0.618051932886312    0.5133351094842772
# ..                   ...                  ...                   ...
# 294   0.2210696878556493   0.3378117379839196    0.5206545921911911
# 295   1.1800774256803745   1.2833280985489552    0.9729532582695294
# 296   0.6777483079306701   0.2410508926188804   0.21140908137640496
# 297   0.6958992752396777   0.5373976903140307   0.31104461154872504
# 298   1.4383397353716147   1.9732778820649939    1.9230625375993606
