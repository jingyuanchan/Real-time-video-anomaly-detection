# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Road/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='CANNY')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='CANNY')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 299

# %%
x = [0] * 198
y =[1]*101
z=x+y
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.0006899153181308163 0.00020129164763971633 0...      0
# 1    0.004736418278459056 0.006683833089531099 0.00...      0
# 2    0.015926059246817104 0.015783879497682153 0.02...      0
# 3    0.00656930761618765 0.005739022074230638 0.020...      0
# 4    0.007799502844220055 0.009599920047153888 0.00...      0
# ..                                                 ...    ...
# 294  0.00605408581174067 0.004449781703959115 0.005...      1
# 295  0.005853614336770956 0.005739022074230638 0.01...      1
# 296  0.0017241260974915275 0.0003162414244498878 0....      1
# 297  0.008142583272609092 0.0028436749015722214 0.0...      1
# 298  0.01692074175970544 0.020524343270947765 0.029...      1
#
# [299 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Road/CDI_Based/Entropy/CSV/Canny.csv')
display(data_df)
# Out:
#                          0                       1                      2  \
# 0    0.0006899153181308163  0.00020129164763971633  0.0001149658209033623
# 1     0.004736418278459056    0.006683833089531099   0.005395361351115228
# 2     0.015926059246817104    0.015783879497682153   0.021629043581703776
# 3      0.00656930761618765    0.005739022074230638    0.02083601931135068
# 4     0.007799502844220055    0.009599920047153888   0.007084428510404871
# ..                     ...                     ...                    ...
# 294    0.00605408581174067    0.004449781703959115   0.005882218143214036
# 295   0.005853614336770956    0.005739022074230638   0.017886438703358508
# 296  0.0017241260974915275   0.0003162414244498878   0.000747414843408485
# 297   0.008142583272609092   0.0028436749015722214   0.002413215534087535
# 298    0.01692074175970544    0.020524343270947765   0.029112111817281995
#
#                          3                       4                      5  \
# 0    0.0012358533381425928  0.00017248828584149895   5.75270497153481e-05
# 1     0.005252116382285584    0.007513482094246496  0.0055385919373393865
# 2     0.020552649545826317     0.02431635154538038    0.02369450423606331
# 3      0.02097768238445854    0.008171226564405646    0.00304456894633547
# 4     0.005882218143214036    0.004994290614383131   0.003417534182578364
# ..                     ...                     ...                    ...
# 294  0.0045931071784861095    0.009571391055945247    0.02160075938329437
# 295   0.014048239618661904     0.01510126610214499    0.01062768986845761
# 296   0.016011343136159952   0.0015230472070033895  0.0017241260974915275
# 297   0.006368994272657724    0.005681808139519168  0.0019825411704065153
# 298    0.03725394180926803     0.04787541970857931    0.04929069551470525
#
#                          6                       7                       8  \
