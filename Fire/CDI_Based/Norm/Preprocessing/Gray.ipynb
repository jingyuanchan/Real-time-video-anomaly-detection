# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Fire/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start)
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            intensity=np.linalg.norm(cdi,ord=2)
            in_list.append(intensity)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start)
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            intensity=np.linalg.norm(cdi,ord=2)
            in_list.append(intensity)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 268

# %%
x = [0] * 126
y =[1]*142
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    1775.435517829399 1540.1436612483135 648.46089...      0
# 1    1130.2984813387316 1220.7916455992217 837.6766...      0
# 2    1496.558267705243 986.393189490991 1133.054697...      0
# 3    450.3971560042172 318.077750932613 401.0837580...      0
# 4    1507.3024347927997 1827.982881678384 1946.7131...      0
# ..                                                 ...    ...
# 263  1139.962602858195 1440.5893006753581 1256.5338...      1
# 264  1043.6172583498237 1013.5572043277617 726.3523...      1
# 265  608.2405144063109 843.1302309864134 638.213818...      1
# 266  1980.9592384394045 3298.205366694175 1853.4689...      1
# 267  593.0251169166512 434.15693343657387 740.56857...      1
#
# [268 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Fire/CDI_Based/Norm/CSV/Gray.csv')
display(data_df)
# Out:
#                       0                   1                   2  \
# 0     1775.435517829399  1540.1436612483135   648.4608902930942
# 1    1130.2984813387316  1220.7916455992217   837.6766995136733
# 2     1496.558267705243    986.393189490991  1133.0546974803256
# 3     450.3971560042172    318.077750932613  401.08375801544497
# 4    1507.3024347927997   1827.982881678384  1946.7131808289796
# ..                  ...                 ...                 ...
# 263   1139.962602858195  1440.5893006753581   1256.533807800513
# 264  1043.6172583498237  1013.5572043277617   726.3523237741224
# 265   608.2405144063109   843.1302309864134   638.2138184153042
# 266  1980.9592384394045   3298.205366694175  1853.4689382777453
# 267   593.0251169166512  434.15693343657387   740.5685719929251
#
#                       3                   4                   5  \
# 0    1691.3153365671149  1571.2669387240926  1641.3792182754612
# 1    1301.1989426701866   883.0362196823869   1171.165525906543
# 2    1389.9364666829233  1175.7350881539537   933.2991882676419
# 3     880.3615890382877   733.6362912823312   809.4099768100699
# 4    1570.0575664503456  1696.9951716058051  2539.3981662144183
# ..                  ...                 ...                 ...
# 263   1743.204317808286  3249.2696402278525  3130.0704405334322
# 264   892.1711263650682   8003.486272318932   2587.145908281227
# 265  1693.0048984803748  2471.0517229634956  2601.7852374873473
