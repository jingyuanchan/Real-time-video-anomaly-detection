# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/jingy/Jupyter/Crime/Fire/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'
# Out:
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Fire\CDI_Based\Entropy\Preprocessing\image_preprocessing\cdi_process.ipynb
# importing Jupyter notebook from C:\Users\jingy\Jupyter\Crime\Fire\CDI_Based\Entropy\Preprocessing\image_preprocessing\calc_entropy.ipynb

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='CANNY')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='CANNY')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 268

# %%
x = [0] * 126
y =[1]*142
z=x+y
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.008028260851102665 0.007456339465660842 0.00...      0
# 1    0.01057067281414233 0.00902863272193223 0.0076...      0
# 2    0.02623666373167117 0.023581449223544628 0.021...      0
# 3    0.009628448462741078 0.009799863077189094 0.01...      0
# 4    0.031194364719462436 0.029506288280903757 0.02...      0
# ..                                                 ...    ...
# 263  0.032346667987484555 0.03223433047027284 0.030...      1
# 264  0.0035609630994651678 0.007542138085788493 0.0...      1
# 265  0.00023000845653928855 5.75270497153481e-05 5....      1
# 266  0.01839742844793665 0.016778748430255234 0.026...      1
# 267  0.0076564996719189855 0.005309433230375608 0.0...      1
#
# [268 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/jingy/Jupyter/Crime/Fire/CDI_Based/Entropy/CSV/Canny.csv')
display(data_df)
# Out:
#                           0                     1                      2  \
# 0      0.008028260851102665  0.007456339465660842    0.00900000675715516
# 1       0.01057067281414233   0.00902863272193223  0.0076564996719189855
# 2       0.02623666373167117  0.023581449223544628   0.021940470098330566
# 3      0.009628448462741078  0.009799863077189094   0.016551409992707065
# 4      0.031194364719462436  0.029506288280903757   0.025756859703441763
# ..                      ...                   ...                    ...
# 263    0.032346667987484555   0.03223433047027284   0.030181788606186397
# 264   0.0035609630994651678  0.007542138085788493   0.002212233065238108
# 265  0.00023000845653928855  5.75270497153481e-05   5.75270497153481e-05
# 266     0.01839742844793665  0.016778748430255234    0.02603915751591494
# 267   0.0076564996719189855  0.005309433230375608   0.011540672885136244
#
#                          3                     4                     5  \
# 0     0.008800036115070827  0.007113007591622313  0.004822380897474388
# 1    0.0061399690594364014   0.00679826376001013  0.009457098487324005
# 2      0.02281780928322504   0.02083601931135068  0.025643974896134493
# 3     0.017943243497016415  0.018879805303959996   0.01913509838480875
# 4      0.02668811967515979    0.0259826857405102  0.026321312557091407
# ..                     ...                   ...                   ...
# 263   0.039826572356061976   0.03753384246581901   0.05178442917363347
# 264   0.004277806456374601   0.02654704520227942  0.009285727750235047
# 265   0.019844055546558964  0.021997108625574052    0.0259826857405102
